# %% [markdown]
# <a href="https://colab.research.google.com/github/whiteBerryJ/AI_assignment/blob/master/1%EC%A3%BC%EC%B0%A8%20%EA%B3%BC%EC%A0%9C_%EC%A0%95%EC%A7%84%EA%B7%A0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### 1주차 과제
#  인공지능과 기술
#  =================
# > 2016년의 알파고 쇼크를 시작된 인공지능에 대한 세계적 관심은 오늘날 2020년에는 일상적인 것이 되었다. 그동안 인공지능이 적용된 기술들은 '신기한 것'으로 인식되어 대중에게 강한 인상을 심어주었는데 이제는 생활의 한 부분으로 인식되기 시작한 것 같다. 이러한 흐름에서 2020년 현재, 어떤 인공지능 기술들이 우리 생활에 적용되기 시작했는 지 알아보자.
#
#  ## 1. 식당 AI서빙로봇 '푸두봇'
# > 최근 우리는 covid-19 사태로 인해 '사회적 거리두기'가 큰 화두가 되고 있는 만큼 사람간의 접촉이 지양되는 시기에 직면했다. 이러한 시기에 가장 큰 타격을 맞는 서비스직은 위험군으로, 항상 covid-19에 대한 경각심을 갖고 일을 해야 하는 상태이다. 이 서비스직종의 한 종류로 식당의 서빙 종사자들에게는 생계의 위협이 될 수도 있겠지만 최근 사태에 대한 떠오른는 대안으로 식당 AI서빙로봇 '푸두봇'이 개발되어 적용된 사례가 화제가 되었다. <br>
# 이와 관련한 기사에서 VD컴퍼니에서 개발한 푸두봇은 "컨트롤과 맵핑 센서를 통해 미리 경로를 잡아주고, 근거리 송수신기를 통해 제어하는 방식이다. 사람이나 장애물을 피해 자율운전기능, 지능적 장애물 회피, 자동 경로탐색 등이 가능하다. 테이블 음식 서빙은 물론 식기 수거, 물컵 등 잔심부름도 가능하다."고 설명하였다. 또 이 기사에 의하면 이 로봇은 "자율주행차에 들어가는 '동시적 위치추정 및 지도 작성(SLAM)' 기술을 갖춰 실시간 현재 위치 파악과 최적의 이동 경로 탐색, 장애물 회피 등이 가능하다."고 하였다. 이는 실시간으로 매장 내의 이동하는 사람과 충돌하지 않고 경로를 계산하여 손님에게 음식을 가져다 준다는 것이다. 이러한 방식에는 인공지능 기술의 한 분야인 자율주행이라는 기능이 활용되었고, 이 분야는 매우 광범위하게 쓰일 가능성이 무궁무진하다. 이는 사람 간 접촉이 지양되는 이 시기에 적합한 기술일 것이다. 따라서 이번 covid-19사태에서 우리가 어떻게 위기 이후를 살아가게 될 지에 대한 하나의 가능성을 이 로봇이 보여주었다고 생각한다. <br> (1) 권혜미 기자, ""음식 나르고 잔심부름까지"...AI 서빙로봇 '푸두봇' 등장", ZD Net Korea, 2019/03/08
# ## 2. 음성 개인비서 - 시리와 빅스비
# > 한국에 사는 대부분의 사람들이 사용하는 스마트 폰에는 인공지능 비서 앱이 적용되어 있다. 애플은 '시리', 삼성은 '빅스비'가 그것이다. 아직 최근 1~2년 안에 제조된 스마트폰이 아니라면 그 기능은 매우 제한되어있긴 하지만 최근에 제조된 해당 회사의 스마트폰이라면 최신의 인공비서가 탑재되어 있다. 이들 인공 비서들은 사용자의 패턴에 맞게 기념일을 추천해주기도 하고 날씨에 관한 정보를 아침에 제공하며 우산이 필요한가에 대한 질문등에도 적절한 대답을 하였다.또 한 기사에 의하면 빅스비에 '집에 도착하면 우유를 사라고 리마인드해줘'라고 말했더니 사용자가 집에 도착했을 때, 빅스비가 우유를 사라는 팝업을 띄웠다고 하였다. 이는 삼성의 지도 어플리케이션을 활용하여 사용자의 명령에 맞는 행동을 할 수 있었다는 것을 보여준다. 그리고 인공지능 비서에게 어쩌면 큰 중요요소라 할 수 있는 챗봇의 기능도 현재 훌륭히 해내고 있는 것을 볼 수 있다. 시리에게 '남자친구 소개시켜줘'라는 다소 웃긴 말을 전달하면 처음엔 '죄송합니다. 제가 답변할 수 없는 질문이예요'라고 말하더니 그 다음에는 '인연은 스스로 만들어가는 거래요'라고 말했고 그 다음에는 '당신을 위한 스마트 매칭을 시작해야겠어요^^' 라며 이모티콘을 동반한 답변을 하였다. 이는 시리의 챗봇기능이 광범위한 질문에 어떤 답을 할 지 스스로 학습하며 이에 맞는 적절한 이모티콘까지 넣을 수 있다는 것을 볼 수 있다. 이렇게 인공 비서는 초기의 모델과는 다르게 이제는 약간이지만 사람과 같은 기능을 수행할 수 있었다. 앞으로 인공지능이라는 분야가 더 발달하고 더 많은 어플리케이션과 연동할 수 있다면 공상영화에 나오는 인공지능 비서와 같은 역할을 수행할 수 있지 않을까 기대해 본다.<br>
# (2)왕진화 기자, "일상 활용도 높아지는 빅스비와 시리…개인 비서 역할 '톡톡', 뉴스웍스, 2019/11/09
#
# ## 3. 알파고, 게임 인공지능
